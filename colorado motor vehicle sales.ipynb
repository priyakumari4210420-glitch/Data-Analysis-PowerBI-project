# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt # visulalizing data
# %matplotlib inline
import seaborn as sns

# %%
df= pd.read_csv('colorado_motor_vehicle_sales.csv')

# %%
df.shape
# Out:
# (501, 4)

# %%
df.head(10)
# Out:
#    year  quarter              county      sales
# 0  2008        1               Adams  231609000
# 1  2008        1            Arapahoe  550378000
# 2  2008        1  Boulder/Broomfield  176771000
# 3  2008        1              Denver  200103000
# 4  2008        1             Douglas   93259000
# 5  2008        1             El Paso  325737000
# 6  2008        1             Fremont    9911000
# 7  2008        1            Garfield   55701000
# 8  2008        1           Jefferson  277611000
# 9  2008        1            La Plata   19558000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 501 entries, 0 to 500
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   year     501 non-null    int64
#  1   quarter  501 non-null    int64
#  2   county   501 non-null    object
#  3   sales    501 non-null    int64
# dtypes: int64(3), object(1)
# memory usage: 15.8+ KB

# %%
pd.isnull(df)
# Out:
#       year  quarter  county  sales
# 0    False    False   False  False
# 1    False    False   False  False
# 2    False    False   False  False
# 3    False    False   False  False
# 4    False    False   False  False
# ..     ...      ...     ...    ...
# 496  False    False   False  False
# 497  False    False   False  False
# 498  False    False   False  False
# 499  False    False   False  False
# 500  False    False   False  False
#
# [501 rows x 4 columns]

# %%
# check for null values

# %%
pd.isnull(df).sum()
# Out:
# year       0
# quarter    0
# county     0
# sales      0
# dtype: int64

# %%
df['sales'].dtypes
# Out:
# dtype('int64')

# %%
df.columns
# Out:
# Index(['year', 'quarter', 'county', 'sales'], dtype='object')

# %%
#rename columns
df.rename(columns={'county' : 'country'})
# Out:
#      year  quarter             country      sales
# 0    2008        1               Adams  231609000
# 1    2008        1            Arapahoe  550378000
# 2    2008        1  Boulder/Broomfield  176771000
# 3    2008        1              Denver  200103000
# 4    2008        1             Douglas   93259000
# ..    ...      ...                 ...        ...
# 496  2015        4             Larimer  244327000
# 497  2015        4                Mesa   88202000
# 498  2015        4              Pueblo   94606000
# 499  2015        4       Rest of State  157059000
# 500  2015        4                Weld  192583000
#
# [501 rows x 4 columns]

# %%
# describe ()method returns desvription of the data in the DataFrame.

# %%
df.describe()
# Out:
#               year     quarter         sales
# count   501.000000  501.000000  5.010000e+02
# mean   2011.570858    2.502994  1.760585e+08
# std       2.266599    1.120041  1.642055e+08
# min    2008.000000    1.000000  6.274000e+06
# 25%    2010.000000    2.000000  6.148200e+07
# 50%    2012.000000    3.000000  1.385820e+08
# 75%    2014.000000    4.000000  2.241580e+08
# max    2015.000000    4.000000  9.169100e+08

# %%
# use describe () for specific column

# %%
df[['year']].describe()
# Out:
#               year
# count   501.000000
# mean   2011.570858
# std       2.266599
# min    2008.000000
# 25%    2010.000000
# 50%    2012.000000
# 75%    2014.000000
# max    2015.000000

# %%
Data Preparation:

# %%
# convert date columns to datetime format

# %%
d=pd.date_range('1-1-2008' , periods=367)
d
# Out:
# DatetimeIndex(['2008-01-01', '2008-01-02', '2008-01-03', '2008-01-04',
#                '2008-01-05', '2008-01-06', '2008-01-07', '2008-01-08',
#                '2008-01-09', '2008-01-10',
#                ...
#                '2008-12-23', '2008-12-24', '2008-12-25', '2008-12-26',
#                '2008-12-27', '2008-12-28', '2008-12-29', '2008-12-30',
#                '2008-12-31', '2009-01-01'],
#               dtype='datetime64[ns]', length=367, freq='D')

# %%
df=pd.DataFrame(d,columns=['dates'])
df
# Out:
#          dates
# 0   2008-01-01
# 1   2008-01-02
# 2   2008-01-03
# 3   2008-01-04
# 4   2008-01-05
# ..         ...
# 362 2008-12-28
# 363 2008-12-29
# 364 2008-12-30
# 365 2008-12-31
# 366 2009-01-01
#
# [367 rows x 1 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   dates   367 non-null    datetime64[ns]
# dtypes: datetime64[ns](1)
# memory usage: 3.0 KB

# %%
df['dates'].dt.year
# Out:
# 0      2008
# 1      2008
# 2      2008
# 3      2008
# 4      2008
#        ...
# 362    2008
# 363    2008
# 364    2008
# 365    2008
# 366    2009
# Name: dates, Length: 367, dtype: int32

# %%
df['year']=df['dates'].dt.year
df['months']=df['dates'].dt.month
df['days']=df['dates'].dt.day
df['weeks']=df['dates'].dt.day_name()

# %%
df
# Out:
#          dates  year  months  days      weeks
# 0   2008-01-01  2008       1     1    Tuesday
# 1   2008-01-02  2008       1     2  Wednesday
# 2   2008-01-03  2008       1     3   Thursday
# 3   2008-01-04  2008       1     4     Friday
# 4   2008-01-05  2008       1     5   Saturday
# ..         ...   ...     ...   ...        ...
# 362 2008-12-28  2008      12    28     Sunday
# 363 2008-12-29  2008      12    29     Monday
# 364 2008-12-30  2008      12    30    Tuesday
# 365 2008-12-31  2008      12    31  Wednesday
# 366 2009-01-01  2009       1     1   Thursday
#
# [367 rows x 5 columns]

# %%
Is there any duplicate dates ?

# %%
df['dates'].nunique()
# Out:
# 367

# %%
df['dates'].duplicated().sum()
# Out:
# 0

# %%
Check from missing values

# %%
df['dates'].isnull().sum()
# Out:
# 0

# %%
df.sort_values('dates',ascending=False)
# Out:
#          dates  year  months  days      weeks
# 366 2009-01-01  2009       1     1   Thursday
# 365 2008-12-31  2008      12    31  Wednesday
# 364 2008-12-30  2008      12    30    Tuesday
# 363 2008-12-29  2008      12    29     Monday
# 362 2008-12-28  2008      12    28     Sunday
# ..         ...   ...     ...   ...        ...
# 4   2008-01-05  2008       1     5   Saturday
# 3   2008-01-04  2008       1     4     Friday
# 2   2008-01-03  2008       1     3   Thursday
# 1   2008-01-02  2008       1     2  Wednesday
# 0   2008-01-01  2008       1     1    Tuesday
#
# [367 rows x 5 columns]

# %%
df.head()
# Out:
#        dates  year  months  days      weeks
# 0 2008-01-01  2008       1     1    Tuesday
# 1 2008-01-02  2008       1     2  Wednesday
# 2 2008-01-03  2008       1     3   Thursday
# 3 2008-01-04  2008       1     4     Friday
# 4 2008-01-05  2008       1     5   Saturday

# %%
df.groupby(['months'])['days'].max()
# Out:
# months
# 1     31
# 2     29
# 3     31
# 4     30
# 5     31
# 6     30
# 7     31
# 8     31
# 9     30
# 10    31
# 11    30
# 12    31
# Name: days, dtype: int32

# %%
df.groupby(['months','year'])['days'].max()
# Out:
# months  year
# 1       2008    31
#         2009     1
# 2       2008    29
# 3       2008    31
# 4       2008    30
# 5       2008    31
# 6       2008    30
# 7       2008    31
# 8       2008    31
# 9       2008    30
# 10      2008    31
# 11      2008    30
# 12      2008    31
# Name: days, dtype: int32

# %%
pd.set_option('display.max_rows',None)

# %%
df.groupby(['months','year'])['days'].max()
# Out:
# months  year
# 1       2008    31
#         2009     1
# 2       2008    29
# 3       2008    31
# 4       2008    30
# 5       2008    31
# 6       2008    30
# 7       2008    31
# 8       2008    31
# 9       2008    30
# 10      2008    31
# 11      2008    30
# 12      2008    31
# Name: days, dtype: int32

# %%
df.columns
# Out:
# Index(['dates', 'year', 'months', 'days', 'weeks'], dtype='object')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('colorado_motor_vehicle_sales.csv')
x=df['year']
h=df['sales']

# %%
plt.bar(x,h,align='edge',color=['red','green','yellow'],edgecolor='black')
plt.xlabel("year of sales")
plt.ylabel("Total sales in lakh Rs.")
# Out:
# Text(0, 0.5, 'Total sales in lakh Rs.')

# %%
df['sales'].value_counts()
# Out:
# sales
# 194231000    2
# 9879000      2
# 209599000    2
# 138918000    2
# 31291000     2
#             ..
# 221631000    1
# 41261000     1
# 8884000      1
# 302807000    1
# 192583000    1
# Name: count, Length: 492, dtype: int64

# %%
df['year'].value_counts()
# Out:
# year
# 2010    64
# 2011    64
# 2012    64
# 2013    64
# 2014    64
# 2015    64
# 2009    61
# 2008    56
# Name: count, dtype: int64

# %%
plt.hist(df['year']);

# %%
df['county'].value_counts()
# Out:
# county
# Adams                 32
# Arapahoe              32
# Weld                  32
# Pueblo                32
# Mesa                  32
# Larimer               32
# La Plata              32
# Jefferson             32
# Garfield              32
# Fremont               32
# El Paso               32
# Douglas               32
# Denver                32
# Boulder               28
# Broomfield            28
# Rest of State         25
# Boulder/Broomfield     4
# Name: count, dtype: int64

# %%
plt.hist(df['sales']);

# %%
df['quarter'].value_counts()
# Out:
# quarter
# 4    126
# 1    125
# 2    125
# 3    125
# Name: count, dtype: int64

# %%
plt.hist(df['quarter']);

# %%
df.head()
# Out:
#    year  quarter              county      sales
# 0  2008        1               Adams  231609000
# 1  2008        1            Arapahoe  550378000
# 2  2008        1  Boulder/Broomfield  176771000
# 3  2008        1              Denver  200103000
# 4  2008        1             Douglas   93259000

# %%
df.shape
# Out:
# (501, 4)

# %%
df.dtypes
# Out:
# year        int64
# quarter     int64
# county     object
# sales       int64
# dtype: object

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      year  quarter              county      sales
# 0    2008        1               Adams  231609000
# 1    2008        1            Arapahoe  550378000
# 2    2008        1  Boulder/Broomfield  176771000
# 3    2008        1              Denver  200103000
# 4    2008        1             Douglas   93259000
# ..    ...      ...                 ...        ...
# 496  2015        4             Larimer  244327000
# 497  2015        4                Mesa   88202000
# 498  2015        4              Pueblo   94606000
# 499  2015        4       Rest of State  157059000
# 500  2015        4                Weld  192583000
#
# [501 rows x 4 columns]>

# %%
pd.read_csv('colorado_motor_vehicle_sales.csv')
# Out:
#      year  quarter              county      sales
# 0    2008        1               Adams  231609000
# 1    2008        1            Arapahoe  550378000
# 2    2008        1  Boulder/Broomfield  176771000
# 3    2008        1              Denver  200103000
# 4    2008        1             Douglas   93259000
# ..    ...      ...                 ...        ...
# 496  2015        4             Larimer  244327000
# 497  2015        4                Mesa   88202000
# 498  2015        4              Pueblo   94606000
# 499  2015        4       Rest of State  157059000
# 500  2015        4                Weld  192583000
#
# [501 rows x 4 columns]

# %%
#Numerical data
#1.relplot

# %%
# relplot-relationship find

# %%
sns.relplot(x='year',y='sales',size='quarter',style='quarter',data=df)

# %%
sns.relplot(x='year',y='sales',size='quarter',style='quarter',col='quarter',data=df)

# %%
df.groupby(['county'])['sales'].sum()
# Out:
# county
# Adams                  8902115000
# Arapahoe              20142323000
# Boulder                4742532000
# Boulder/Broomfield      677201000
# Broomfield             1027326000
# Denver                 6763613000
# Douglas                3236493000
# El Paso               11926044000
# Fremont                 316939000
# Garfield               1600594000
# Jefferson              9058407000
# La Plata                792807000
# Larimer                5344367000
# Mesa                   2621436000
# Pueblo                 2384044000
# Rest of State          3582170000
# Weld                   5086889000
# Name: sales, dtype: int64

# %%
sns.boxplot(data=df,x='quarter',y='sales',hue='quarter')
plt.title('Sales Distribution by Quarter')
plt.show()

# %%
df.groupby(['county'])['sales'].sum()
# Out:
# county
# Adams                  8902115000
# Arapahoe              20142323000
# Boulder                4742532000
# Boulder/Broomfield      677201000
# Broomfield             1027326000
# Denver                 6763613000
# Douglas                3236493000
# El Paso               11926044000
# Fremont                 316939000
# Garfield               1600594000
# Jefferson              9058407000
# La Plata                792807000
# Larimer                5344367000
# Mesa                   2621436000
# Pueblo                 2384044000
# Rest of State          3582170000
# Weld                   5086889000
# Name: sales, dtype: int64

# %%
sns.barplot(x='sales',y='county',hue='county',ci=None ,data=df);
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_6476\2134470499.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x='sales',y='county',hue='county',ci=None ,data=df);

# %%
CONCLUSION:
This project provides a comprehensive analysis of Colorado motor vehicle sales data, including data Collection ,preparation
exploratory analysis , statistical analysis, and predictive modeling. With continued innovation ,customer motor vehicle sales 
are expected to maintain steady growth in the future.
